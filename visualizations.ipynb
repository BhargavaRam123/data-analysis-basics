# %%
# !pip install numpy
# !pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.0 MB 1.9 MB/s eta 0:00:04
#    --- ------------------------------------ 0.8/8.0 MB 1.7 MB/s eta 0:00:05
#    ------ --------------------------------- 1.3/8.0 MB 1.6 MB/s eta 0:00:05
#    ------- -------------------------------- 1.6/8.0 MB 1.6 MB/s eta 0:00:04
#    --------- ------------------------------ 1.8/8.0 MB 1.6 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.1/8.0 MB 1.7 MB/s eta 0:00:04
#    ------------- -------------------------- 2.6/8.0 MB 1.6 MB/s eta 0:00:04
#    -------------- ------------------------- 2.9/8.0 MB 1.6 MB/s eta 0:00:04
#    ---------------- ----------------------- 3.4/8.0 MB 1.7 MB/s eta 0:00:03
#    ------------------- -------------------- 3.9/8.0 MB 1.8 MB/s eta 0:00:03
#    -------------------- ------------------- 4.2/8.0 MB 1.8 MB/s eta 0:00:03
# ...

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\bharg\Downloads\Ice Cream Ratings.csv")
df.set_index("Date")
# Out:
#           Flavor Rating  Texture Rating  Overall Rating
# Date
# 1/1/2022       0.223090        0.040220        0.600129
# 1/2/2022       0.635886        0.938476        0.106264
# 1/3/2022       0.442323        0.044154        0.598112
# 1/4/2022       0.389128        0.549676        0.489353
# 1/5/2022       0.386887        0.519439        0.988280
# 1/6/2022       0.877984        0.193588        0.832827
# 1/7/2022       0.140995        0.325110        0.105147

# %%
df.plot(kind='line',title ='ice cream ratings')
# Out:
# <Axes: title={'center': 'ice cream ratings'}>

# %%
df.plot(kind='bar',stacked = True,title ='ice cream ratings')
# Out:
# <Axes: title={'center': 'ice cream ratings'}>
